# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data_sample.csv", encoding="latin1")

# %%
print("Shape:", df.shape)
# Out:
# Shape: (2823, 25)

# %%
df.columns
# Out:
# Index(['ï»¿ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='str')

# %%
df.dtypes
# Out:
# ï»¿ORDERNUMBER        int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE               str
# STATUS                  str
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE             str
# MSRP                  int64
# PRODUCTCODE             str
# CUSTOMERNAME            str
# PHONE                   str
# ADDRESSLINE1            str
# ADDRESSLINE2            str
# CITY                    str
# STATE                   str
# POSTALCODE              str
# COUNTRY                 str
# TERRITORY               str
# CONTACTLASTNAME         str
# CONTACTFIRSTNAME        str
# DEALSIZE                str
# dtype: object

# %%
df.isnull().sum()
# Out:
# ï»¿ORDERNUMBER         0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ï»¿ORDERNUMBER, QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CUSTOMERNAME, PHONE, ADDRESSLINE1, ADDRESSLINE2, CITY, STATE, POSTALCODE, COUNTRY, TERRITORY, CONTACTLASTNAME, CONTACTFIRSTNAME, DEALSIZE, ADDRESSLINE]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Length: 2823, dtype: bool

# %%
df["ORDERDATE"] = pd.to_datetime(df["ORDERDATE"], format = "mixed")

# %%
df["ADDRESSLINE2"] = df["ADDRESSLINE2"].fillna("unknown")

# %%
df["STATE"] = df["STATE"].fillna("unknown")

# %%
df["TERRITORY"] = df["TERRITORY"].fillna("unknown")

# %%
df["POSTALCODE"] = df["POSTALCODE"].fillna("Unknown")

# %%
df.head(10)
# Out:
#    ï»¿ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# 5           10168               36      96.66                1  3479.76
# 6           10180               29      86.13                9  2497.77
# 7           10188               48     100.00                1  5512.32
# 8           10201               22      98.57                2  2168.54
# 9           10211               41     100.00               14  4708.44
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0 2003-02-24  Shipped       1         2     2003  ...          NaN
# ...

# %%
df.tail()
# Out:
#       ï»¿ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818           10350               20     100.00               15  2244.40
# 2819           10373               29     100.00                1  3978.51
# 2820           10386               43     100.00                4  5417.57
# 2821           10397               34      62.24                1  2116.16
# 2822           10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 2818 2004-12-02   Shipped       4        12     2004  ...          NaN
# 2819 2005-01-31   Shipped       1         1     2005  ...          NaN
# 2820 2005-03-01  Resolved       1         3     2005  ...          NaN
# 2821 2005-03-28   Shipped       1         3     2005  ...          NaN
# 2822 2005-05-06   On Hold       2         5     2005  ...          NaN
#
#           CITY    STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
df.sample()
# Out:
#       ï»¿ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 1699           10192               46       83.6                2  3845.6
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2    CITY  \
# 1699 2003-11-20  Shipped       4        11     2003  ...          NaN  Nashua
#
#      STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 1699    NH      62005     USA   unknown           Young          Valarie
#
#      DEALSIZE ADDRESSLINE
# 1699   Medium     unknown
#
# [1 rows x 26 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ï»¿ORDERNUMBER    2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[us]
#  6   STATUS            2823 non-null   str
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   str
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   str
#  13  CUSTOMERNAME      2823 non-null   str
#  14  PHONE             2823 non-null   str
#  15  ADDRESSLINE1      2823 non-null   str
#  16  ADDRESSLINE2      2823 non-null   str
# ...

# %%
df.describe()
# Out:
#        ï»¿ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count     2823.000000      2823.000000  2823.000000      2823.000000
# mean     10258.725115        35.092809    83.658544         6.466171
# min      10100.000000         6.000000    26.880000         1.000000
# 25%      10180.000000        27.000000    68.860000         3.000000
# 50%      10262.000000        35.000000    95.700000         6.000000
# 75%      10333.500000        43.000000   100.000000         9.000000
# max      10425.000000        97.000000   100.000000        18.000000
# std         92.085478         9.741443    20.174277         4.225841
#
#               SALES                   ORDERDATE       QTR_ID     MONTH_ID  \
# count   2823.000000                        2823  2823.000000  2823.000000
# mean    3553.889072  2004-05-11 00:16:49.989373     2.717676     7.092455
# min      482.130000         2003-01-06 00:00:00     1.000000     1.000000
# ...

# %%
df.iloc[0:3, 0:2]
# Out:
#    ï»¿ORDERNUMBER  QUANTITYORDERED
# 0           10107               30
# 1           10121               34
# 2           10134               41

# %%
df.iloc[-1]
# Out:
# ï»¿ORDERNUMBER                    10414
# QUANTITYORDERED                      47
# PRICEEACH                         65.52
# ORDERLINENUMBER                       9
# SALES                           3079.44
# ORDERDATE           2005-05-06 00:00:00
# STATUS                          On Hold
# QTR_ID                                2
# MONTH_ID                              5
# YEAR_ID                            2005
# PRODUCTLINE                       Ships
# MSRP                                 54
# PRODUCTCODE                    S72_3212
# CUSTOMERNAME          Gifts4AllAges.com
# PHONE                        6175559555
# ADDRESSLINE1         8616 Spinnaker Dr.
# ADDRESSLINE2                    unknown
# CITY                             Boston
# STATE                                MA
# POSTALCODE                        51003
# COUNTRY                             USA
# TERRITORY                       unknown
# CONTACTLASTNAME                 Yoshido
# ...

# %%
df[1:5]
# Out:
#    ï»¿ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 1 2003-05-07  Shipped       2         5     2003  ...      unknown
# 2 2003-07-01  Shipped       3         7     2003  ...      unknown
# 3 2003-08-25  Shipped       3         8     2003  ...      unknown
# 4 2003-10-10  Shipped       4        10     2003  ...      unknown
#
#             CITY    STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 1          Reims  unknown      51100  France      EMEA         Henriot
# 2          Paris  unknown      75508  France      EMEA        Da Cunha
# ...

# %%
df[df["SALES"]>5000]
# Out:
#       ï»¿ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4              10159               49      100.0               14  5205.27
# 7              10188               48      100.0                1  5512.32
# 20             10341               41      100.0                9  7737.93
# 25             10417               66      100.0                2  7516.08
# 26             10103               26      100.0               11  5404.62
# ...              ...              ...        ...              ...      ...
# 2685           10361               44      100.0               10  5001.92
# 2686           10375               44      100.0               11  5208.72
# 2689           10401               77       92.0                9  7084.00
# 2715           10397               48      100.0                3  5192.64
# 2820           10386               43      100.0                4  5417.57
#
# ...

# %%
df["STATUS"].value_counts()
# Out:
# STATUS
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: count, dtype: int64

# %%
df["YEAR_ID"].value_counts()
# Out:
# YEAR_ID
# 2004    1345
# 2003    1000
# 2005     478
# Name: count, dtype: int64

# %%
df["PRODUCTLINE"].value_counts()
# Out:
# PRODUCTLINE
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: count, dtype: int64

# %%
df[df["SALES"]>7000]
# Out:
#       ï»¿ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 20             10341               41     100.00                9  7737.93
# 25             10417               66     100.00                2  7516.08
# 27             10112               29     100.00                1  7209.11
# 28             10126               38     100.00               11  7329.06
# 29             10140               37     100.00               11  7374.10
# ...              ...              ...        ...              ...      ...
# 2586           10401               85      88.75               10  7543.75
# 2634           10336               46     100.00                2  9558.80
# 2656           10318               50     100.00                8  7119.00
# 2662           10388               50     100.00                3  7154.50
# 2689           10401               77      92.00                9  7084.00
#
# ...

# %%
df[df["TERRITORY"]=="EMEA" & df["COUNTRY"]=="SWEDEN"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df[df["TERRITORY"]=="EMEA" & df["COUNTRY"]=="SWEDEN"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:76, in OpsMixin.__rand__(self, other)
#      74 @unpack_zerodim_and_defer("__rand__")
#      75 def __rand__(self, other):
# ---> 76     return self._logical_method(other, roperator.rand_)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6746, in Series._logical_method(self, other, op)
# ...

# %%
df[df["SALES"].between(900, 1000)]
# Out:
#       ï»¿ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 645            10331               30      32.47                8  974.10
# 780            10425               19      49.22               10  935.18
# 819            10285               20      49.06               10  981.20
# 853            10380               21      47.18                8  990.78
# 1511           10343               27      36.21                6  977.67
# 1544           10173               31      31.53                9  977.43
# 1550           10243               33      29.54                1  974.82
# 1618           10124               22      45.25                1  995.50
# 1624           10205               24      38.08                4  913.92
# 1724           10195               32      28.29                7  905.28
# 1792           10109               29      32.10                6  930.90
# 1799           10192               30      30.59               13  917.70
# ...

# %%
df[df["CITY"].isin("Cambridge", "Munich", "Sevilla")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df[df["CITY"].isin("Cambridge", "Munich", "Sevilla")]
#
# TypeError: Series.isin() takes 2 positional arguments but 4 were given

# %%
groups = df.groupby("COUNTRY")

# %%
groups["SALES"].sum()
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
df.groupby("CITY")["SALES"].count()
# Out:
# CITY
# Aaarhus         27
# Allentown       31
# Barcelona       23
# Bergamo         48
# Bergen          29
#                 ..
# Toulouse        20
# Tsawassen       26
# Vancouver       22
# Versailles      18
# White Plains    26
# Name: SALES, Length: 73, dtype: int64

# %%
groups["CONCAT(FIRSTNAME"&"CONCATLASTNAME"].agg(["sum", "mean", "max", "min", "count"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 groups["CONCATFIRSTNAME"&"CONCATLASTNAME"].agg(["sum", "mean", "max", "min", "count"])
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
